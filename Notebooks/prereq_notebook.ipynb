# %% [markdown]
# #Salutations!
# ##My name is Christian Dennis
# ##What do I do?
# I am currently employed as an operations analyst, though nearly our entire workload is done through Excel!
# Before my current position, I worked in retail and then customer service. I have experience in sales, operations, management, and tech servicing, and I am excited to develop my skills further for a future in tech.
# ##What do I know?
# I studied Studio Art at Berea College, graduating in 2020. I also completed the Web Development pathway with Code:You in December of 2025. This Data Analytics pathway is an opportunity to challenge myself and further expand my understanding!
# ##Who do I follow and serve?
# ###The Alpha and the Omega, the First and the Last, the Beginning and the End.

# %%
print("Let's vibe and let's code, but let's not vibe code!")
# Out:
# Let's vibe and let's code, but let's not vibe code!
